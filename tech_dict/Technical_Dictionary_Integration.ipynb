# %%
import re,string
def read_dic(dicname):
    dic=open(dicname,"r")
    line= dic.read()
    line=line.split('\n')
    ewords = []
    hwords = []
    for i in line :
        str1=re.split(r' <>+ ', i)
        ewords+=str1[::2]  #list slicing 
        hwords+=str1[1::2] #list slicing
    return ewords,hwords  
def gen_eng_log(e_corpus) :
    word = []
    eng=open("eng_words.log","w")
    elist,hlist=read_dic("/home/kishori/a/Alignment1/dictionary/technical_geography_dictionary")
    f = open(e_corpus, 'r')
    line= f.read()
    line= line.split('\n')
    for j in elist :
        count=0
        sent_no = []
        for i in range(len(line)-1) :
            
            words=line[i].strip(string.punctuation).split()
            for k in words :
                s=""
                if j.lower() == k.lower() :
                        str1=j+"\t"+str(i)
                        word.append(str1)
    for i in word :
        eng.write(i+'\n')
        #print(i)
def temp_dic_form(logfile) :
    ewords = []
    elist,hlist=read_dic("/home/kishori/a/Alignment1/dictionary/technical_geography_dictionary")
    gen_eng_log("/home/kishori/a/Alignment1/BUgol2.1E")
    #print(elist)
    log=open(logfile,'r+')
    word=log.read()
    list1=word.strip().split("\n")
    for i in list1 :
        str1=i.split('\t')
        ewords+=str1[::2]  #list slicing
        #sent_no+=str1[1::2] #list slicing
    list4=[]
    k=0
    for i in range(len(elist)):
        for k in range(len(ewords)):
        #print(elist[i])
        #print(list1[k])
            if elist[i] == ewords[k] :
                str1=ewords[k]+"\t"+hlist[i]
                if str1 not in list4 :
                    list4.append(str1)
            
    f= open("temp.txt","w+")
    for i in list4:
        f.write(i+"\n")     
def fact_generation(H_corpus) :
    temp_dic_form("/home/kishori/a/Alignment1/tech_dict/eng_words.log")
    dic=open("/home/kishori/a/Alignment1/tech_dict/temp.txt","r")
    log=open("/home/kishori/a/Alignment1/tech_dict/eng_words.log","r")
    word=log.read()
    sent_no = []
    e_words = []
    fact_list = []
    list1=word.strip().split("\n")
    for i in list1 : #log_data
        str1=i.split('\t')
        e_words+=str1[::2]  #list slicing
        sent_no+=str1[1::2] #list slicing
    h_corpus=open(H_corpus,"r")
    corpus=h_corpus.read()
    corpus= corpus.strip(string.punctuation).split('\n')
    line=dic.read()
    line=line.strip().split("\n")
    ewords = []
    hwords = []
    for i in line : #dic_data
        str1=i.split('\t')
        ewords+=str1[::2]  #list slicing
        hwords+=str1[1::2] #list slicing
    for i in range(len(corpus)-1) :
        for j in range(len(sent_no)) :
            if int(sent_no[j]) == i :
                for k in range(len(ewords)) :    #temp_dictionary
                    if e_words[j] == ewords[k] :
                        hwords[k] = re.sub(r" ?\([^)]+\)", "", hwords[k])
                        list1 = re.split('; |, |[0-9]. ',hwords[k])
                        while("" in list1) : 
                            list1.remove("")
                        #print(list1)
                        words=corpus[i].strip(string.punctuation).split()
                        for x in words :
                                for l in list1 :
                                    if l == x :
                                        #print(e_words[k],x)
                                        str1="(Ewords-mfs-Hwords-sentno\t"+ ewords[k] + "\tmfs\t" + x +"\t"+ str(i+1) + ")"
                                        if str1 not in fact_list :
                                            fact_list.append(str1)
    fact=open("facts.dat","w+")
    for i in fact_list :
        fact.write(i+"\n")
        print(i)
    
                        #fact.write("(Ewords-mfs-Hwords-sentno\t"+ ewords[int(sent_no[j])] + "\tmfs\t" + j +"\t"+ str(k+1) + ")\n")
#elist,hlist=read_dic("/home/nupur/Task2/technical_geography_dictionary")
#print(elist)
fact_generation("/home/kishori/a/Alignment1/BUgol2.1H")
# Out:
# (Ewords-mfs-Hwords-sentno	Physical	mfs	BOwika	1)
# (Ewords-mfs-Hwords-sentno	Country	mfs	xeSa	2)
# (Ewords-mfs-Hwords-sentno	Country	mfs	xeSa	5)
# (Ewords-mfs-Hwords-sentno	Place	mfs	sWAna	9)
# (Ewords-mfs-Hwords-sentno	Soil	mfs	mqxA	9)
# (Ewords-mfs-Hwords-sentno	Deposition	mfs	nikRepaNa	13)
# (Ewords-mfs-Hwords-sentno	Erosion	mfs	aparaxana	13)
# (Ewords-mfs-Hwords-sentno	Formation	mfs	nirmANa	14)
# (Ewords-mfs-Hwords-sentno	Physical	mfs	BOwika	14)
# (Ewords-mfs-Hwords-sentno	Theory	mfs	sixXAMwa	15)
# (Ewords-mfs-Hwords-sentno	Crust	mfs	parpatI	16)
# (Ewords-mfs-Hwords-sentno	Earth	mfs	pqWvI	16)
# (Ewords-mfs-Hwords-sentno	Continental	mfs	mahAxvIpIya	17)
# (Ewords-mfs-Hwords-sentno	Volcanic	mfs	jvAlAmuKIya	17)
# (Ewords-mfs-Hwords-sentno	Boundary	mfs	parisImA	19)
# (Ewords-mfs-Hwords-sentno	Boundary	mfs	parisImA	20)
# (Ewords-mfs-Hwords-sentno	Boundary	mfs	parisImA	22)
# (Ewords-mfs-Hwords-sentno	Transform	mfs	rUpAMwara	22)
# (Ewords-mfs-Hwords-sentno	Position	mfs	sWiwi	23)
# (Ewords-mfs-Hwords-sentno	Size	mfs	AkAra	23)
# (Ewords-mfs-Hwords-sentno	Evolution	mfs	vikAsa	24)
# (Ewords-mfs-Hwords-sentno	Part	mfs	BAga	26)
# (Ewords-mfs-Hwords-sentno	South	mfs	xakRiNa	27)
# (Ewords-mfs-Hwords-sentno	North	mfs	uwwara	28)
# (Ewords-mfs-Hwords-sentno	Folded	mfs	valiwa	30)
# (Ewords-mfs-Hwords-sentno	Form	mfs	rUpa	30)
# (Ewords-mfs-Hwords-sentno	Sedimentary	mfs	avasAxI	30)
# (Ewords-mfs-Hwords-sentno	Ancient	mfs	prAcIna	31)
# (Ewords-mfs-Hwords-sentno	Continent	mfs	mahAxvIpa	31)
# (Ewords-mfs-Hwords-sentno	Land	mfs	BUmi	31)
# (Ewords-mfs-Hwords-sentno	Part	mfs	BAga	31)
# (Ewords-mfs-Hwords-sentno	Basin	mfs	xroNI	32)
# (Ewords-mfs-Hwords-sentno	Formation	mfs	nirmANa	32)
# (Ewords-mfs-Hwords-sentno	Northern	mfs	uwwarI	32)
# (Ewords-mfs-Hwords-sentno	Plateau	mfs	paTAra	32)
# (Ewords-mfs-Hwords-sentno	North	mfs	uwwara	33)
# (Ewords-mfs-Hwords-sentno	South	mfs	xakRiNa	33)
# (Ewords-mfs-Hwords-sentno	Time	mfs	samaya	33)
# (Ewords-mfs-Hwords-sentno	Northern	mfs	uwwarI	34)
# (Ewords-mfs-Hwords-sentno	Land	mfs	BUmi	35)
# (Ewords-mfs-Hwords-sentno	Physical	mfs	BOwika	35)
# (Ewords-mfs-Hwords-sentno	Plateau	mfs	paTAra	36)
# (Ewords-mfs-Hwords-sentno	Surface	mfs	sawaha	36)
# (Ewords-mfs-Hwords-sentno	Land	mfs	BUmi	37)
# (Ewords-mfs-Hwords-sentno	Stable	mfs	sWira	37)
# (Ewords-mfs-Hwords-sentno	Himalayas	mfs	himAlaya	38)
# (Ewords-mfs-Hwords-sentno	Northern	mfs	uwwarI	38)
# (Ewords-mfs-Hwords-sentno	Mountain	mfs	parvawa	40)
# (Ewords-mfs-Hwords-sentno	Topography	mfs	sWalAkqwi	40)
# (Ewords-mfs-Hwords-sentno	Northern	mfs	uwwarI	41)
# (Ewords-mfs-Hwords-sentno	Igneous	mfs	Agneya	42)
# (Ewords-mfs-Hwords-sentno	Plateau	mfs	paTAra	42)
# (Ewords-mfs-Hwords-sentno	Northern	mfs	uwwarI	46)
# (Ewords-mfs-Hwords-sentno	Direction	mfs	xiSA	47)
# (Ewords-mfs-Hwords-sentno	Mountain	mfs	parvawa	47)
# (Ewords-mfs-Hwords-sentno	Himalayas	mfs	himAlaya	48)
# (Ewords-mfs-Hwords-sentno	Mountain	mfs	parvawa	48)
# (Ewords-mfs-Hwords-sentno	Eastern	mfs	pUrvI	50)
# (Ewords-mfs-Hwords-sentno	Western	mfs	paScimI	50)
# (Ewords-mfs-Hwords-sentno	Longitudinal	mfs	xeSAMwarIya	51)
# (Ewords-mfs-Hwords-sentno	Himalayas	mfs	himAlaya	53)
# (Ewords-mfs-Hwords-sentno	Inner	mfs	AMwarika	53)
# (Ewords-mfs-Hwords-sentno	Northern	mfs	uwwarI	53)
# (Ewords-mfs-Hwords-sentno	Average	mfs	Osawa	54)
# (Ewords-mfs-Hwords-sentno	Himalayas	mfs	himAlaya	56)
# (Ewords-mfs-Hwords-sentno	Core	mfs	kroda	57)
# (Ewords-mfs-Hwords-sentno	Granite	mfs	grenAita	57)
# (Ewords-mfs-Hwords-sentno	Himalayas	mfs	himAlaya	57)
# (Ewords-mfs-Hwords-sentno	Part	mfs	BAga	57)
# (Ewords-mfs-Hwords-sentno	Range	mfs	SqMKalA	58)
# (Ewords-mfs-Hwords-sentno	Himalayas	mfs	himAlaya	59)
# (Ewords-mfs-Hwords-sentno	Range	mfs	SqMKalA	61)
# (Ewords-mfs-Hwords-sentno	South	mfs	xakRiNa	61)
# (Ewords-mfs-Hwords-sentno	Altitude	mfs	UzcAI	63)
# (Ewords-mfs-Hwords-sentno	Average	mfs	Osawa	63)
# (Ewords-mfs-Hwords-sentno	Width	mfs	cOdZAI	63)
# (Ewords-mfs-Hwords-sentno	Range	mfs	SqMKalA	64)
# (Ewords-mfs-Hwords-sentno	Range	mfs	SqMKalA	65)
# (Ewords-mfs-Hwords-sentno	Valley	mfs	GAtI	65)
# (Ewords-mfs-Hwords-sentno	Hill	mfs	pahAdZI	66)
# (Ewords-mfs-Hwords-sentno	Region	mfs	kRewra	66)
# (Ewords-mfs-Hwords-sentno	State	mfs	sWiwi	67)
# (Ewords-mfs-Hwords-sentno	Himalayas	mfs	himAlaya	68)
# (Ewords-mfs-Hwords-sentno	Range	mfs	SqMKalA	68)
# (Ewords-mfs-Hwords-sentno	Altitude	mfs	UzcAI	69)
# (Ewords-mfs-Hwords-sentno	Width	mfs	cOdZAI	69)
# (Ewords-mfs-Hwords-sentno	Main	mfs	muKya	70)
# (Ewords-mfs-Hwords-sentno	North	mfs	uwwara	70)
# (Ewords-mfs-Hwords-sentno	Valley	mfs	GAtI	72)
# (Ewords-mfs-Hwords-sentno	East	mfs	pUrva	74)
# (Ewords-mfs-Hwords-sentno	Himalayas	mfs	himAlaya	74)
# (Ewords-mfs-Hwords-sentno	West	mfs	paScima	74)
# (Ewords-mfs-Hwords-sentno	River	mfs	naxI	75)
# (Ewords-mfs-Hwords-sentno	East	mfs	pUrva	76)
# (Ewords-mfs-Hwords-sentno	Himalayas	mfs	himAlaya	76)
# (Ewords-mfs-Hwords-sentno	Part	mfs	BAga	76)
# (Ewords-mfs-Hwords-sentno	West	mfs	paScima	76)
# (Ewords-mfs-Hwords-sentno	Himalayas	mfs	himAlaya	77)
# (Ewords-mfs-Hwords-sentno	Part	mfs	BAga	77)
# (Ewords-mfs-Hwords-sentno	Himalayas	mfs	himAlaya	78)
# (Ewords-mfs-Hwords-sentno	Himalayas	mfs	himAlaya	79)
# (Ewords-mfs-Hwords-sentno	Regional	mfs	kRewrIya	79)
# (Ewords-mfs-Hwords-sentno	Boundary	mfs	sImA	80)
# (Ewords-mfs-Hwords-sentno	Eastern	mfs	pUrvI	80)
# (Ewords-mfs-Hwords-sentno	Himalayas	mfs	himAlaya	80)
# (Ewords-mfs-Hwords-sentno	Bend	mfs	modZa	81)
# (Ewords-mfs-Hwords-sentno	Boundary	mfs	sImA	81)
# (Ewords-mfs-Hwords-sentno	Eastern	mfs	pUrvI	81)
# (Ewords-mfs-Hwords-sentno	Himalayas	mfs	himAlaya	81)
# (Ewords-mfs-Hwords-sentno	South	mfs	xakRiNa	81)
# (Ewords-mfs-Hwords-sentno	Eastern	mfs	pUrvI	82)
# (Ewords-mfs-Hwords-sentno	Sedimentary	mfs	avasAxI	83)
# (Ewords-mfs-Hwords-sentno	Northern	mfs	uwwarI	86)
# (Ewords-mfs-Hwords-sentno	Northern	mfs	uwwarI	87)
# (Ewords-mfs-Hwords-sentno	River	mfs	naxI	87)
# (Ewords-mfs-Hwords-sentno	Soil	mfs	mqxA	88)
# (Ewords-mfs-Hwords-sentno	Basin	mfs	besina	89)
# (Ewords-mfs-Hwords-sentno	Area	mfs	kRewra	90)
# (Ewords-mfs-Hwords-sentno	Climate	mfs	jalavAyu	92)
# (Ewords-mfs-Hwords-sentno	Favourable	mfs	anukUla	92)
# (Ewords-mfs-Hwords-sentno	Soil	mfs	mqxA	92)
# (Ewords-mfs-Hwords-sentno	Water	mfs	pAnI	92)
# (Ewords-mfs-Hwords-sentno	Northern	mfs	uwwarI	93)
# (Ewords-mfs-Hwords-sentno	Work	mfs	kArya	93)
# (Ewords-mfs-Hwords-sentno	Formation	mfs	nirmANa	94)
# (Ewords-mfs-Hwords-sentno	River	mfs	naxI	94)
# (Ewords-mfs-Hwords-sentno	Riverine	mfs	naxIya	94)
# (Ewords-mfs-Hwords-sentno	Silt	mfs	gAxa	95)
# (Ewords-mfs-Hwords-sentno	Water	mfs	pAnI	97)
# (Ewords-mfs-Hwords-sentno	Water	mfs	pAnI	98)
# (Ewords-mfs-Hwords-sentno	Northern	mfs	uwwarI	99)
# (Ewords-mfs-Hwords-sentno	Northern	mfs	uwwarI	100)
# (Ewords-mfs-Hwords-sentno	Part	mfs	BAga	100)
# (Ewords-mfs-Hwords-sentno	Western	mfs	paScimI	100)
# (Ewords-mfs-Hwords-sentno	Part	mfs	BAga	101)

# %%
def fact_generation(H_corpus) :
    temp_dic_form("/home/nupur/Task2/eng_words.log")
    dic=open("/home/nupur/Task2/temp.txt","r")
    log=open("/home/nupur/Task2/eng_words.log","r")
    word=log.read()
    sent_no = []
    e_words = []
    fact_list = []
    list1=word.strip().split("\n")
    for i in list1 : #log_data
        str1=i.split('\t')
        e_words+=str1[::2]  #list slicing
        sent_no+=str1[1::2] #list slicing
    h_corpus=open(H_corpus,"r")
    
    corpus=h_corpus.read()
    corpus= corpus.strip(string.punctuation).split('\n')
    line=dic.read()
    line=line.strip().split("\n")
    ewords = []
    hwords = []
    for i in line : #dic_data
        str1=i.split('\t')
        ewords+=str1[::2]  #list slicing
        hwords+=str1[1::2] #list slicing
    
    for i in range(len(hwords)) :
        for j in range(len(sent_no)) :
            if i == int(sent_no[j]) :
                hwords[i] = re.sub(r" ?\([^)]+\)", "", hwords[i])
                list1 = re.split('; |, |[0-9]. ',hwords[i])
                while("" in list1) : 
                    list1.remove("")
                for z in list1 :
                    for k in range(len(corpus)-1) :
                        words=corpus[k].strip(string.punctuation).split()
                        str1=""
                        for x in words :
                                if z == x :
                                    str1="(Ewords-mfs-Hwords-sentno\t"+ ewords[int(sent_no[j])] + "\tmfs\t" + x +"\t"+ str(k+1) + ")"
                                    if str1 not in fact_list :
                                        fact_list.append(str1)
    fact=open("facts.dat","w+")
    for i in fact_list :
        fact.write(i+"\n")
        print(i)
                
                        #fact.write("(Ewords-mfs-Hwords-sentno\t"+ ewords[int(sent_no[j])] + "\tmfs\t" + j +"\t"+ str(k+1) + ")\n")
#elist,hlist=read_dic("/home/nupur/Task2/technical_geography_dictionary")
#print(elist)
fact_generation("/home/nupur/Task2/BUgol2.1H")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-e2bb1489edb7> in <module>
#      49 #elist,hlist=read_dic("/home/nupur/Task2/technical_geography_dictionary")
#      50 #print(elist)
# ---> 51 fact_generation("/home/nupur/Task2/BUgol2.1H")
#
# <ipython-input-2-e2bb1489edb7> in fact_generation(H_corpus)
#       1 def fact_generation(H_corpus) :
# ----> 2     temp_dic_form("/home/nupur/Task2/eng_words.log")
#       3     dic=open("/home/nupur/Task2/temp.txt","r")
#       4     log=open("/home/nupur/Task2/eng_words.log","r")
#       5     word=log.read()
#
# <ipython-input-1-f35d2347fb3c> in temp_dic_form(logfile)
#      37     gen_eng_log("/home/kishori/a/Alignment1/BUgol2.1E")
#      38     #print(elist)
# ---> 39     log=open(logfile,'r+')
#      40     word=log.read()
#      41     list1=word.strip().split("\n")
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/nupur/Task2/eng_words.log'

# %%
def fact_generation(H_corpus) :
    temp_dic_form("/home/nupur/Task2/eng_words.log")
    dic=open("/home/nupur/Task2/temp.txt","r")
    log=open("/home/nupur/Task2/eng_words.log","r")
    word=log.read()
    sent_no = []
    list1=word.strip().split("\n")
    for i in list1 : #log_data
        str1=i.split('\t')
        #e_words+=str1[::2]  #list slicing
        sent_no+=str1[1::2] #list slicing
    h_corpus=open(H_corpus,"r")
    fact=open("facts.dat","w+")
    corpus=h_corpus.read()
    corpus= corpus.strip(string.punctuation).split('\n')
    line=dic.read()
    line=line.strip().split("\n")
    ewords = []
    hwords = []
    for i in line : #dic_data
        str1=i.split('\t')
        ewords+=str1[::2]  #list slicing
        hwords+=str1[1::2] #list slicing
    for i in range(len(hwords)) :
    #list1=hwords[i].split('/','.')
        hwords[i] = re.sub(r" ?\([^)]+\)", "", hwords[i])
        list1 = re.split('; |, |[0-9]. ',hwords[i])
        while("" in list1) : 
            list1.remove("") 
        print(list1)
        for j in list1 :
            for k in range(len(corpus)-1) :
                words=corpus[k].strip(string.punctuation).split()
                str1=""
                for x in words :
                    if j == x and int(sent_no[i]) == k:
                        fact.write("(Ewords-mfs-Hwords-sentno\t"+ ewords[i] + "\tmfs\t" + j +"\t"+ str(k+1) + ")\n")
#elist,hlist=read_dic("/home/nupur/Task2/technical_geography_dictionary")
#print(elist)
fact_generation("/home/nupur/Task2/BUgol2.1H")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-2e098bb66f59> in <module>()
#      46 #elist,hlist=read_dic("/home/nupur/Task2/technical_geography_dictionary")
#      47 #print(elist)
# ---> 48 fact_generation("/home/nupur/Task2/BUgol2.1H")
#
# <ipython-input-2-2e098bb66f59> in fact_generation(H_corpus)
#       1 def fact_generation(H_corpus) :
# ----> 2     temp_dic_form("/home/nupur/Task2/eng_words.log")
#       3     dic=open("/home/nupur/Task2/temp.txt","r")
#       4     log=open("/home/nupur/Task2/eng_words.log","r")
#       5     word=log.read()
#
# NameError: name 'temp_dic_form' is not defined
